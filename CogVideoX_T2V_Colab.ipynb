# %% [markdown]
# ## CogVideoX Text-to-Video
#
# This notebook demonstrates how to run [CogVideoX-2b](https://huggingface.co/THUDM/CogVideoX-2b) and [CogVideoX-5b](https://huggingface.co/THUDM/CogVideoX-5b) with 🧨 Diffusers on a free-tier Colab GPU.
#
# Additional resources:
# - [Docs](https://huggingface.co/docs/diffusers/en/api/pipelines/cogvideox)
# - [Quantization with TorchAO](https://github.com/sayakpaul/diffusers-torchao/)
# - [Quantization with Quanto](https://gist.github.com/a-r-r-o-w/31be62828b00a9292821b85c1017effa)
#
# Note: If, for whatever reason, you randomly get an OOM error, give it a try on Kaggle T4 instances instead. I've found that Colab free-tier T4 can be unreliable at times. Sometimes, the notebook will run smoothly, but other times it will crash with an error 🤷🏻‍♂️

# %% [markdown]
# #### Install the necessary requirements

# %%
# %pip install diffusers transformers hf_transfer
# Out:
# Requirement already satisfied: diffusers in ./sbonetto_venv/lib/python3.10/site-packages (0.31.0)
# Requirement already satisfied: transformers in ./sbonetto_venv/lib/python3.10/site-packages (4.46.3)
# Requirement already satisfied: hf_transfer in ./sbonetto_venv/lib/python3.10/site-packages (0.1.8)
# Requirement already satisfied: safetensors>=0.3.1 in ./sbonetto_venv/lib/python3.10/site-packages (from diffusers) (0.4.5)
# Requirement already satisfied: importlib-metadata in ./sbonetto_venv/lib/python3.10/site-packages (from diffusers) (8.5.0)
# Requirement already satisfied: numpy in ./sbonetto_venv/lib/python3.10/site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in ./sbonetto_venv/lib/python3.10/site-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: huggingface-hub>=0.23.2 in ./sbonetto_venv/lib/python3.10/site-packages (from diffusers) (0.26.2)
# Requirement already satisfied: Pillow in ./sbonetto_venv/lib/python3.10/site-packages (from diffusers) (11.0.0)
# Requirement already satisfied: filelock in ./sbonetto_venv/lib/python3.10/site-packages (from diffusers) (3.16.1)
# Requirement already satisfied: requests in ./sbonetto_venv/lib/python3.10/site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: pyyaml>=5.1 in ./sbonetto_venv/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: packaging>=20.0 in ./sbonetto_venv/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: tqdm>=4.27 in ./sbonetto_venv/lib/python3.10/site-packages (from transformers) (4.67.0)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in ./sbonetto_venv/lib/python3.10/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./sbonetto_venv/lib/python3.10/site-packages (from huggingface-hub>=0.23.2->diffusers) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in ./sbonetto_venv/lib/python3.10/site-packages (from huggingface-hub>=0.23.2->diffusers) (2024.10.0)
# Requirement already satisfied: zipp>=3.20 in ./sbonetto_venv/lib/python3.10/site-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./sbonetto_venv/lib/python3.10/site-packages (from requests->diffusers) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./sbonetto_venv/lib/python3.10/site-packages (from requests->diffusers) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./sbonetto_venv/lib/python3.10/site-packages (from requests->diffusers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./sbonetto_venv/lib/python3.10/site-packages (from requests->diffusers) (3.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install git+https://github.com/huggingface/accelerate
# %pip install accelerate==0.33.0
# Out:
# Collecting git+https://github.com/huggingface/accelerate
#   Cloning https://github.com/huggingface/accelerate to /tmp/pip-req-build-6ab7uhac
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/accelerate /tmp/pip-req-build-6ab7uhac
#   Resolved https://github.com/huggingface/accelerate to commit 8ade23cc6aec7c3bd3d80fef6378cafaade75bbe
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: packaging>=20.0 in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==1.1.0.dev0) (24.2)
# Requirement already satisfied: safetensors>=0.4.3 in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==1.1.0.dev0) (0.4.5)
# Requirement already satisfied: torch>=1.10.0 in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==1.1.0.dev0) (2.5.1)
# Requirement already satisfied: psutil in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==1.1.0.dev0) (6.1.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==1.1.0.dev0) (0.26.2)
# Requirement already satisfied: pyyaml in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==1.1.0.dev0) (6.0.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==1.1.0.dev0) (1.26.4)
# Requirement already satisfied: filelock in ./sbonetto_venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate==1.1.0.dev0) (3.16.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./sbonetto_venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate==1.1.0.dev0) (4.12.2)
# Requirement already satisfied: requests in ./sbonetto_venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate==1.1.0.dev0) (2.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in ./sbonetto_venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate==1.1.0.dev0) (2024.10.0)
# Requirement already satisfied: tqdm>=4.42.1 in ./sbonetto_venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate==1.1.0.dev0) (4.67.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (12.4.127)
# Requirement already satisfied: networkx in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (3.4.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (12.4.127)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (2.21.5)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (12.4.5.8)
# Requirement already satisfied: jinja2 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (3.1.4)
# Requirement already satisfied: triton==3.1.0 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (3.1.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (1.13.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==1.1.0.dev0) (11.2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./sbonetto_venv/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.10.0->accelerate==1.1.0.dev0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./sbonetto_venv/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate==1.1.0.dev0) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./sbonetto_venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate==1.1.0.dev0) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./sbonetto_venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate==1.1.0.dev0) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in ./sbonetto_venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate==1.1.0.dev0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./sbonetto_venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate==1.1.0.dev0) (2024.8.30)
# Building wheels for collected packages: accelerate
#   Building wheel for accelerate (pyproject.toml) ... done
#   Created wheel for accelerate: filename=accelerate-1.1.0.dev0-py3-none-any.whl size=333339 sha256=8fee06936c9b64e1e91a214f6337b27be50235a9261f980b856d9e17fccd0244
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zbnu_1s7/wheels/f6/c7/9d/1b8a5ca8353d9307733bc719107acb67acdc95063bba749f26
# Successfully built accelerate
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.33.0
#     Uninstalling accelerate-0.33.0:
#       Successfully uninstalled accelerate-0.33.0
# Successfully installed accelerate-1.1.0.dev0
# Note: you may need to restart the kernel to use updated packages.
# Collecting accelerate==0.33.0
#   Using cached accelerate-0.33.0-py3-none-any.whl (315 kB)
# Requirement already satisfied: safetensors>=0.3.1 in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==0.33.0) (0.4.5)
# Requirement already satisfied: huggingface-hub>=0.21.0 in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==0.33.0) (0.26.2)
# Requirement already satisfied: pyyaml in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==0.33.0) (6.0.2)
# Requirement already satisfied: packaging>=20.0 in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==0.33.0) (24.2)
# Requirement already satisfied: psutil in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==0.33.0) (6.1.0)
# Requirement already satisfied: torch>=1.10.0 in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==0.33.0) (2.5.1)
# Requirement already satisfied: numpy<2.0.0,>=1.17 in ./sbonetto_venv/lib/python3.10/site-packages (from accelerate==0.33.0) (1.26.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./sbonetto_venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate==0.33.0) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in ./sbonetto_venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate==0.33.0) (2024.10.0)
# Requirement already satisfied: filelock in ./sbonetto_venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate==0.33.0) (3.16.1)
# Requirement already satisfied: requests in ./sbonetto_venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate==0.33.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in ./sbonetto_venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate==0.33.0) (4.67.0)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (11.2.1.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (1.13.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (12.4.5.8)
# Requirement already satisfied: triton==3.1.0 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (3.1.0)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (11.6.1.9)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (10.3.5.147)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (2.21.5)
# Requirement already satisfied: jinja2 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (12.4.127)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (12.3.1.170)
# Requirement already satisfied: networkx in ./sbonetto_venv/lib/python3.10/site-packages (from torch>=1.10.0->accelerate==0.33.0) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./sbonetto_venv/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.10.0->accelerate==0.33.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./sbonetto_venv/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate==0.33.0) (3.0.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./sbonetto_venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate==0.33.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./sbonetto_venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate==0.33.0) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in ./sbonetto_venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate==0.33.0) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./sbonetto_venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate==0.33.0) (3.4.0)
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.1.0.dev0
#     Uninstalling accelerate-1.1.0.dev0:
#       Successfully uninstalled accelerate-1.1.0.dev0
# Successfully installed accelerate-0.33.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Import required libraries

# %% [markdown]
# The following block is optional but if enabled, downloading models from the HF Hub will be much faster

# %%
import os
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

# %%
import torch
from diffusers import AutoencoderKLCogVideoX, CogVideoXPipeline, CogVideoXTransformer3DModel
from diffusers.utils import export_to_video
from transformers import T5EncoderModel

# %% [markdown]
# #### Load models and create pipeline
#
# Note: `bfloat16`, which is the recommended dtype for running "CogVideoX-5b" will cause OOM errors due to lack of efficient support on Turing GPUs.
#
# Therefore, we must use `float16`, which might result in poorer generation quality. The recommended solution is to use Ampere or above GPUs, which also support efficient quantization kernels from [TorchAO](https://github.com/pytorch/ao) :(

# %%
# Models: "THUDM/CogVideoX-2b" or "THUDM/CogVideoX-5b"
model_id = "THUDM/CogVideoX-5b"

# %%
# Thank you [@camenduru](https://github.com/camenduru)!
# The reason for using checkpoints hosted by Camenduru instead of the original is because they exported
# with a max_shard_size of "5GB" when saving the model with `.save_pretrained`. The original converted
# model was saved with "10GB" as the max shard size, which causes the Colab CPU RAM to be insufficient
# leading to OOM (on the CPU)

transformer = CogVideoXTransformer3DModel.from_pretrained("camenduru/cogvideox-5b-float16", subfolder="transformer", torch_dtype=torch.float16)
text_encoder = T5EncoderModel.from_pretrained("camenduru/cogvideox-5b-float16", subfolder="text_encoder", torch_dtype=torch.float16)
vae = AutoencoderKLCogVideoX.from_pretrained(model_id, subfolder="vae", torch_dtype=torch.float16)
# Out:
# Downloading shards: 100%|██████████| 3/3 [00:00<00:00, 2424.92it/s]
# Loading checkpoint shards: 100%|██████████| 3/3 [00:00<00:00,  4.67it/s]

# %%
# Create pipeline and run inference
pipe = CogVideoXPipeline.from_pretrained(
    model_id,
    text_encoder=text_encoder,
    transformer=transformer,
    vae=vae,
    torch_dtype=torch.float16,
)
# Out:
# Loading pipeline components...:  40%|████      | 2/5 [00:00<00:00, 2105.05it/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Create pipeline and run inference
# ----> 2 pipe = CogVideoXPipeline.from_pretrained(
#       3     model_id,
#       4     text_encoder=text_encoder,
#       5     transformer=transformer,
#       6     vae=vae,
#       7     torch_dtype=torch.float16,
#       8 )
#
# File ~/CogVideoX-5B_Video_Generation/sbonetto_venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/CogVideoX-5B_Video_Generation/sbonetto_venv/lib/python3.10/site-packages/diffusers/pipelines/pipeline_utils.py:896, in DiffusionPipeline.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     893     loaded_sub_model = passed_class_obj[name]
#     894 else:
#     895     # load sub model
# --> 896     loaded_sub_model = load_sub_model(
#     897         library_name=library_name,
#     898         class_name=class_name,
#     899         importable_classes=importable_classes,
#     900         pipelines=pipelines,
#     901         is_pipeline_module=is_pipeline_module,
#     902         pipeline_class=pipeline_class,
#     903         torch_dtype=torch_dtype,
#     904         provider=provider,
#     905         sess_options=sess_options,
#     906         device_map=current_device_map,
#     907         max_memory=max_memory,
#     908         offload_folder=offload_folder,
#     909         offload_state_dict=offload_state_dict,
#     910         model_variants=model_variants,
#     911         name=name,
#     912         from_flax=from_flax,
#     913         variant=variant,
#     914         low_cpu_mem_usage=low_cpu_mem_usage,
#     915         cached_folder=cached_folder,
#     916         use_safetensors=use_safetensors,
#     917     )
#     918     logger.info(
#     919         f"Loaded {name} as {class_name} from `{name}` subfolder of {pretrained_model_name_or_path}."
#     920     )
#     922 init_kwargs[name] = loaded_sub_model  # UNet(...), # DiffusionSchedule(...)
#
# File ~/CogVideoX-5B_Video_Generation/sbonetto_venv/lib/python3.10/site-packages/diffusers/pipelines/pipeline_loading_utils.py:638, in load_sub_model(library_name, class_name, importable_classes, pipelines, is_pipeline_module, pipeline_class, torch_dtype, provider, sess_options, device_map, max_memory, offload_folder, offload_state_dict, model_variants, name, from_flax, variant, low_cpu_mem_usage, cached_folder, use_safetensors)
#     633     is_dummy_path = none_module.startswith(DUMMY_MODULES_FOLDER) or none_module.startswith(
#     634         TRANSFORMERS_DUMMY_MODULES_FOLDER
#     635     )
#     636     if is_dummy_path and "dummy" in none_module:
#     637         # call class_obj for nice error message of missing requirements
# --> 638         class_obj()
#     640     raise ValueError(
#     641         f"The component {class_obj} of {pipeline_class} cannot be loaded as it does not seem to have"
#     642         f" any of the loading methods defined in {ALL_IMPORTABLE_CLASSES}."
#     643     )
#     645 load_method = getattr(class_obj, load_method_name)
#
# File ~/CogVideoX-5B_Video_Generation/sbonetto_venv/lib/python3.10/site-packages/transformers/utils/dummy_sentencepiece_objects.py:226, in T5Tokenizer.__init__(self, *args, **kwargs)
#     225 def __init__(self, *args, **kwargs):
# --> 226     requires_backends(self, ["sentencepiece"])
#
# File ~/CogVideoX-5B_Video_Generation/sbonetto_venv/lib/python3.10/site-packages/transformers/utils/import_utils.py:1639, in requires_backends(obj, backends)
#    1637 failed = [msg.format(name) for available, msg in checks if not available()]
#    1638 if failed:
# -> 1639     raise ImportError("".join(failed))
#
# ImportError:
# T5Tokenizer requires the SentencePiece library but it was not found in your environment. Checkout the instructions on the
# installation page of its repo: https://github.com/google/sentencepiece#installation and follow the ones
# that match your environment. Please note that you may need to restart your runtime after installation.

# %% [markdown]
# #### Enable memory optimizations
#
# Note that sequential cpu offloading is necessary for being able to run the model on Turing or lower architectures. It aggressively maintains everything on the CPU and only moves the currently executing nn.Module to the GPU. This saves a lot of VRAM but adds a lot of overhead for inference, making generations extremely slow (1 hour+). Unfortunately, this is the only solution for running the model on Colab until efficient kernels are supported.

# %%
pipe.enable_sequential_cpu_offload()
# pipe.vae.enable_tiling()

# %% [markdown]
# #### Generate!

# %%
prompt = (
    "A weary soldier, clad in a dusty, camouflage uniform, stands solemnly in front of the camera, his eyes reflecting a deep sadness and resignation. His face, marked by the grime of battle and the weight of impending conflict, conveys a poignant awareness that the war is imminent. The background is a blur of military activity, hinting at the chaos about to unfold. His posture is rigid yet somehow defeated, as he clutches his helmet in one hand, a symbol of the protection and burden he carries. The somber lighting casts shadows over his features, emphasizing the heavy toll of his duty and the somber realization that his time to face the horrors of war has arrived."
)

# %%
video = pipe(prompt=prompt, guidance_scale=6, use_dynamic_cfg=True, num_inference_steps=50).frames[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
export_to_video(video, "output.mp4", fps=30)
